# %% [markdown]
# #### Dwi Pujining Tyas - PYTN-KS12-004
# Python for Data Science

# %% [markdown]
# # STATISTICS
# Statistical Treatment for Retail Datasets [Assignment Python 2]

# %% [markdown]
# ## Prepping Data

# %%
import numpy as np
import statistics
import math
import scipy.stats
import pandas as pd

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/nyc-rolling-sales.csv')

# %%
df
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %%
df.shape
# Out:
# (84548, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
# ...

# %%
df_baru = pd.read_csv('dataset/nyc-rolling-sales.csv')

# %%
df_baru
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %%
df_baru.rename(columns = {'BOROUGH' : 'wilayah', 
                          'NEIGHBORHOOD' : 'lingkungan', 
                          'BUILDING CLASS CATEGORY' : 'kategori_bangunan', 
                          'TAX CLASS AT PRESENT' : 'kelas_pajak', 
                          'BLOCK' : 'blok', 
                          'LOT' : 'banyak',
                          'EASE-MENT' : 'kenyamanan',
                          'BUILDING CLASS AT PRESENT' : 'kelas_dibangun',
                          'ADDRESS' : 'alamat',
                          'APARTMENT NUMBER' : 'no_apart',
                          'RESIDENTIAL UNITS' : 'unit_hunian',
                          'COMMERCIAL UNITS' : 'unit_komersil',
                          'LAND SQUARE FEET' : 'tanah_persegi',
                          'GROSS SQUARE FEET' : 'kotor_persegi',
                          'YEAR BUILT' : 'tahun_dibangun',
                          'TAX CLASS AT TIME OF SALE' : 'kelaspajak_penjualan',
                          'BUILDING CLASS AT TIME OF SALE' : 'kelasbangunan_penjualan',
                          'SALE PRICE' : 'harga_penjualan',
                          'SALE DATE' : 'tanggal_penjualan'}, inplace = True)

# %%
df_baru.head(10)
# Out:
#    Unnamed: 0  wilayah     lingkungan  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
# 5           9        1  ALPHABET CITY
# 6          10        1  ALPHABET CITY
# 7          11        1  ALPHABET CITY
# 8          12        1  ALPHABET CITY
# 9          13        1  ALPHABET CITY
#
#                              kategori_bangunan kelas_pajak  blok  banyak  \
# 0  07 RENTALS - WALKUP APARTMENTS                       2A   392       6
# 1  07 RENTALS - WALKUP APARTMENTS                        2   399      26
# 2  07 RENTALS - WALKUP APARTMENTS                        2   399      39
# 3  07 RENTALS - WALKUP APARTMENTS                       2B   402      21
# 4  07 RENTALS - WALKUP APARTMENTS                       2A   404      55
# 5  07 RENTALS - WALKUP APARTMENTS                        2   405      16
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Menghapus kolom yang tidak digunakan

# %%
hapus_kolom = ['Unnamed: 0', 'kenyamanan']
df_baru.drop(hapus_kolom, inplace=True, axis=1)

# %%
df_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   wilayah                  84548 non-null  int64
#  1   lingkungan               84548 non-null  object
#  2   kategori_bangunan        84548 non-null  object
#  3   kelas_pajak              84548 non-null  object
#  4   blok                     84548 non-null  int64
#  5   banyak                   84548 non-null  int64
#  6   kelas_dibangun           84548 non-null  object
#  7   alamat                   84548 non-null  object
#  8   no_apart                 84548 non-null  object
#  9   ZIP CODE                 84548 non-null  int64
#  10  unit_hunian              84548 non-null  int64
#  11  unit_komersil            84548 non-null  int64
#  12  TOTAL UNITS              84548 non-null  int64
#  13  tanah_persegi            84548 non-null  object
# ...

# %%
df_baru.isnull().sum()
# Out:
# wilayah                    0
# lingkungan                 0
# kategori_bangunan          0
# kelas_pajak                0
# blok                       0
# banyak                     0
# kelas_dibangun             0
# alamat                     0
# no_apart                   0
# ZIP CODE                   0
# unit_hunian                0
# unit_komersil              0
# TOTAL UNITS                0
# tanah_persegi              0
# kotor_persegi              0
# tahun_dibangun             0
# kelaspajak_penjualan       0
# kelasbangunan_penjualan    0
# harga_penjualan            0
# tanggal_penjualan          0
# dtype: int64

# %%
df_baru.duplicated().sum()
# Out:
# 765

# %%
df_baru = df_baru.drop_duplicates()

# %%
df_baru
# Out:
#        wilayah     lingkungan                            kategori_bangunan  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       kelas_pajak  blok  banyak kelas_dibangun                  alamat  \
# 0              2A   392       6             C2            153 AVENUE B
# 1               2   399      26             C7   234 EAST 4TH   STREET
# ...

# %%
# Out:
#   Input In [147]
#     df_baru['wilayah'] = df_baru['wilayah'].str.replace('1':'Manhattan'
#                                                            ^
# SyntaxError: invalid syntax

# %%
df_baru
# Out:
#        wilayah     lingkungan                            kategori_bangunan  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       kelas_pajak  blok  banyak kelas_dibangun                  alamat  \
# 0              2A   392       6             C2            153 AVENUE B
# 1               2   399      26             C7   234 EAST 4TH   STREET
# ...

# %%
def plot_corr(df, size=11):
    corr = df.corr()
    fig, ax= plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr(df)

# %%
df_baru.corr()
# Out:
#                        wilayah      blok    banyak  ZIP CODE  unit_hunian  \
# wilayah               1.000000  0.417001 -0.277848  0.256564    -0.023229
# blok                  0.417001  1.000000 -0.229118  0.234063    -0.015628
# banyak               -0.277848 -0.229118  1.000000 -0.145802    -0.034303
# ZIP CODE              0.256564  0.234063 -0.145802  1.000000     0.005578
# unit_hunian          -0.023229 -0.015628 -0.034303  0.005578     1.000000
# unit_komersil        -0.005503 -0.003517 -0.010953  0.000726     0.015653
# TOTAL UNITS          -0.023346 -0.015888 -0.033169  0.005415     0.888309
# tahun_dibangun        0.108303  0.071262 -0.289463  0.330708     0.025380
# kelaspajak_penjualan -0.315163 -0.287300  0.296680 -0.142915    -0.001074
#
#                       unit_komersil  TOTAL UNITS  tahun_dibangun  \
# wilayah                   -0.005503    -0.023346        0.108303
# blok                      -0.003517    -0.015888        0.071262
# ...

# %% [markdown]
# ## Statistic Proses

# %% [markdown]
# ### Mean

# %%
df_baru["TOTAL UNITS"].mean()
# Out:
# 2.249183895538629

# %% [markdown]
# ### Median

# %% [markdown]
# ### Modus

# %% [markdown]
# ### Range

# %% [markdown]
# ### Variance

# %% [markdown]
# ### Standard Deviation

# %% [markdown]
# ### Probability Distribution

# %% [markdown]
# ### Confidence Intervals

# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
# ### Prepocessing

# %% [markdown]
# ## Overall Analysis
