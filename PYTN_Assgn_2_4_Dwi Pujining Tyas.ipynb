# %% [markdown]
# #### Dwi Pujining Tyas - PYTN-KS12-004
# Python for Data Science

# %% [markdown]
# # STATISTICS
# Statistical Treatment for Retail Dataset [Assignment Python 2]

# %% [markdown]
# ## Prepping Data

# %%
import numpy as np
import statistics
import math
import scipy.stats as st
import pandas as pd
import datetime as dt

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/nyc-rolling-sales.csv')

# %%
df.tail(50)
# Out:
#        Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84498        8364        5      WOODROW
# 84499        8365        5      WOODROW
# 84500        8366        5      WOODROW
# 84501        8367        5      WOODROW
# 84502        8368        5      WOODROW
# 84503        8369        5      WOODROW
# 84504        8370        5      WOODROW
# 84505        8371        5      WOODROW
# 84506        8372        5      WOODROW
# 84507        8373        5      WOODROW
# 84508        8374        5      WOODROW
# 84509        8375        5      WOODROW
# 84510        8376        5      WOODROW
# 84511        8377        5      WOODROW
# 84512        8378        5      WOODROW
# 84513        8379        5      WOODROW
# 84514        8380        5      WOODROW
# 84515        8381        5      WOODROW
# 84516        8382        5      WOODROW
# 84517        8383        5      WOODROW
# 84518        8384        5      WOODROW
# 84519        8385        5      WOODROW
# ...

# %%
df.shape
# Out:
# (84548, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
# ...

# %%
df_baru = pd.read_csv('dataset/nyc-rolling-sales.csv')

# %%
df_baru
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %%
df_baru.rename(columns = {'BOROUGH' : 'wilayah', 
                          'NEIGHBORHOOD' : 'lingkungan', 
                          'BUILDING CLASS CATEGORY' : 'kategori_bangunan', 
                          'TAX CLASS AT PRESENT' : 'kelas_pajak', 
                          'BLOCK' : 'blok', 
                          'LOT' : 'banyak',
                          'EASE-MENT' : 'kenyamanan',
                          'BUILDING CLASS AT PRESENT' : 'kelas_dibangun',
                          'ADDRESS' : 'alamat',
                          'APARTMENT NUMBER' : 'no_apart',
                          'RESIDENTIAL UNITS' : 'unit_hunian',
                          'COMMERCIAL UNITS' : 'unit_komersil',
                          'LAND SQUARE FEET' : 'tanah_persegi',
                          'GROSS SQUARE FEET' : 'kotor_persegi',
                          'YEAR BUILT' : 'tahun_dibangun',
                          'TAX CLASS AT TIME OF SALE' : 'kelaspajak_penjualan',
                          'BUILDING CLASS AT TIME OF SALE' : 'kelasbangunan_penjualan',
                          'SALE PRICE' : 'harga_penjualan',
                          'SALE DATE' : 'tanggal_penjualan'}, inplace = True)

# %%
df_baru.head(10)
# Out:
#    Unnamed: 0  wilayah     lingkungan  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
# 5           9        1  ALPHABET CITY
# 6          10        1  ALPHABET CITY
# 7          11        1  ALPHABET CITY
# 8          12        1  ALPHABET CITY
# 9          13        1  ALPHABET CITY
#
#                              kategori_bangunan kelas_pajak  blok  banyak  \
# 0  07 RENTALS - WALKUP APARTMENTS                       2A   392       6
# 1  07 RENTALS - WALKUP APARTMENTS                        2   399      26
# 2  07 RENTALS - WALKUP APARTMENTS                        2   399      39
# 3  07 RENTALS - WALKUP APARTMENTS                       2B   402      21
# 4  07 RENTALS - WALKUP APARTMENTS                       2A   404      55
# 5  07 RENTALS - WALKUP APARTMENTS                        2   405      16
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Menghapus kolom yang tidak digunakan

# %%
hapus_kolom = ['Unnamed: 0', 'kenyamanan', 'lingkungan', 'no_apart']
df_baru.drop(hapus_kolom, inplace=True, axis=1)

# %%
df_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   wilayah                  84548 non-null  int64
#  1   kategori_bangunan        84548 non-null  object
#  2   kelas_pajak              84548 non-null  object
#  3   blok                     84548 non-null  int64
#  4   banyak                   84548 non-null  int64
#  5   kelas_dibangun           84548 non-null  object
#  6   alamat                   84548 non-null  object
#  7   ZIP CODE                 84548 non-null  int64
#  8   unit_hunian              84548 non-null  int64
#  9   unit_komersil            84548 non-null  int64
#  10  TOTAL UNITS              84548 non-null  int64
#  11  tanah_persegi            84548 non-null  object
#  12  kotor_persegi            84548 non-null  object
#  13  tahun_dibangun           84548 non-null  int64
# ...

# %% [markdown]
# Mengecek dan menghapus data yang duplikat

# %%
df_baru.duplicated().sum()
# Out:
# 765

# %%
df_baru = df_baru.drop_duplicates()

# %%
df_baru
# Out:
#        wilayah                            kategori_bangunan kelas_pajak  blok  \
# 0            1  07 RENTALS - WALKUP APARTMENTS                       2A   392
# 1            1  07 RENTALS - WALKUP APARTMENTS                        2   399
# 2            1  07 RENTALS - WALKUP APARTMENTS                        2   399
# 3            1  07 RENTALS - WALKUP APARTMENTS                       2B   402
# 4            1  07 RENTALS - WALKUP APARTMENTS                       2A   404
# ...        ...                                          ...         ...   ...
# 84543        5  02 TWO FAMILY DWELLINGS                               1  7349
# 84544        5  02 TWO FAMILY DWELLINGS                               1  7349
# 84545        5  02 TWO FAMILY DWELLINGS                               1  7351
# 84546        5  22 STORE BUILDINGS                                    4  7100
# 84547        5  35 INDOOR PUBLIC AND CULTURAL FACILITIES              4  7105
#
# ...

# %% [markdown]
# Mereplace missing value (-) menjadi NaN pada kolom tanah_persegi, kotor_persegi, harga_penjualan.

# %%
df_baru['tanah_persegi'] = df_baru['tanah_persegi'].replace('[^\d.]', np.nan, regex=True)
# Out:
# /var/folders/4y/l6qtpfl57p39zc4q106yjtqw0000gp/T/ipykernel_687/2033485800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_baru['tanah_persegi'] = df_baru['tanah_persegi'].replace('[^\d.]', np.nan, regex=True)

# %%
df_baru['kotor_persegi'] = df_baru['kotor_persegi'].replace('[^\d.]', np.nan, regex=True)
# Out:
# /var/folders/4y/l6qtpfl57p39zc4q106yjtqw0000gp/T/ipykernel_687/536045715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_baru['kotor_persegi'] = df_baru['kotor_persegi'].replace('[^\d.]', np.nan, regex=True)

# %%
df_baru['harga_penjualan'] = df_baru['harga_penjualan'].replace('[^\d.]', np.nan, regex=True)
# Out:
# /var/folders/4y/l6qtpfl57p39zc4q106yjtqw0000gp/T/ipykernel_687/498712876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_baru['harga_penjualan'] = df_baru['harga_penjualan'].replace('[^\d.]', np.nan, regex=True)

# %%
df_baru.tail(50)
# Out:
#        wilayah                            kategori_bangunan kelas_pajak  blok  \
# 84498        5  01 ONE FAMILY DWELLINGS                               1  7359
# 84499        5  02 TWO FAMILY DWELLINGS                               1  6913
# 84500        5  02 TWO FAMILY DWELLINGS                               1  6913
# 84501        5  02 TWO FAMILY DWELLINGS                               1  6914
# 84502        5  02 TWO FAMILY DWELLINGS                               1  6914
# 84503        5  02 TWO FAMILY DWELLINGS                               1  6919
# 84504        5  02 TWO FAMILY DWELLINGS                               1  6919
# 84505        5  02 TWO FAMILY DWELLINGS                               1  6920
# 84506        5  02 TWO FAMILY DWELLINGS                               1  6920
# 84507        5  02 TWO FAMILY DWELLINGS                               1  6933
# 84508        5  02 TWO FAMILY DWELLINGS                               1  6965
# ...

# %% [markdown]
# Menghapus NaN value

# %%
df_baru.isna().sum()
# Out:
# wilayah                        0
# kategori_bangunan              0
# kelas_pajak                    0
# blok                           0
# banyak                         0
# kelas_dibangun                 0
# alamat                         0
# ZIP CODE                       0
# unit_hunian                    0
# unit_komersil                  0
# TOTAL UNITS                    0
# tanah_persegi              26054
# kotor_persegi              27385
# tahun_dibangun                 0
# kelaspajak_penjualan           0
# kelasbangunan_penjualan        0
# harga_penjualan            14176
# tanggal_penjualan              0
# dtype: int64

# %%
df_baru = df_baru.dropna()

# %%
df_baru.isna().sum()
# Out:
# wilayah                    0
# kategori_bangunan          0
# kelas_pajak                0
# blok                       0
# banyak                     0
# kelas_dibangun             0
# alamat                     0
# ZIP CODE                   0
# unit_hunian                0
# unit_komersil              0
# TOTAL UNITS                0
# tanah_persegi              0
# kotor_persegi              0
# tahun_dibangun             0
# kelaspajak_penjualan       0
# kelasbangunan_penjualan    0
# harga_penjualan            0
# tanggal_penjualan          0
# dtype: int64

# %%
df_baru.head(50)
# Out:
#      wilayah                            kategori_bangunan kelas_pajak  blok  \
# 0          1  07 RENTALS - WALKUP APARTMENTS                       2A   392
# 3          1  07 RENTALS - WALKUP APARTMENTS                       2B   402
# 4          1  07 RENTALS - WALKUP APARTMENTS                       2A   404
# 6          1  07 RENTALS - WALKUP APARTMENTS                       2B   406
# 9          1  08 RENTALS - ELEVATOR APARTMENTS                      2   387
# 11         1  08 RENTALS - ELEVATOR APARTMENTS                     2B   400
# 22         1  09 COOPS - WALKUP APARTMENTS                          2   376
# 172        1  14 RENTALS - 4-10 UNIT                               2A   391
# 173        1  14 RENTALS - 4-10 UNIT                               2A   393
# 174        1  14 RENTALS - 4-10 UNIT                               2A   394
# 195        1  22 STORE BUILDINGS                                    4   390
# ...

# %% [markdown]
# Mengganti tipe data beberapa kolom

# %%
df_baru.dtypes
# Out:
# wilayah                     int64
# kategori_bangunan          object
# kelas_pajak                object
# blok                        int64
# banyak                      int64
# kelas_dibangun             object
# alamat                     object
# ZIP CODE                    int64
# unit_hunian                 int64
# unit_komersil               int64
# TOTAL UNITS                 int64
# tanah_persegi              object
# kotor_persegi              object
# tahun_dibangun              int64
# kelaspajak_penjualan        int64
# kelasbangunan_penjualan    object
# harga_penjualan            object
# tanggal_penjualan          object
# dtype: object

# %%
df_baru['wilayah'] = df_baru['wilayah'].astype(object)
df_baru['blok'] = df_baru['blok'].astype(int)
df_baru['banyak'] = df_baru['banyak'].astype(int)
df_baru['ZIP CODE'] = df_baru['ZIP CODE'].astype(int)
df_baru['unit_hunian'] = df_baru['unit_hunian'].astype(int)
df_baru['unit_komersil'] = df_baru['unit_komersil'].astype(int)
df_baru['TOTAL UNITS'] = df_baru['TOTAL UNITS'].astype(int)
df_baru['tahun_dibangun'] = df_baru['tahun_dibangun'].astype(int)
df_baru['kelaspajak_penjualan'] = df_baru['kelaspajak_penjualan'].astype(int)
df_baru['kotor_persegi'] = df_baru['kotor_persegi'].astype(int)
df_baru['harga_penjualan'] = df_baru['harga_penjualan'].astype(int)
df_baru['tanggal_penjualan'] = df_baru['tanggal_penjualan'].astype('datetime64[ns]')

# %%
df_baru.dtypes
# Out:
# wilayah                            object
# kategori_bangunan                  object
# kelas_pajak                        object
# blok                                int64
# banyak                              int64
# kelas_dibangun                     object
# alamat                             object
# ZIP CODE                            int64
# unit_hunian                         int64
# unit_komersil                       int64
# TOTAL UNITS                         int64
# tanah_persegi                      object
# kotor_persegi                       int64
# tahun_dibangun                      int64
# kelaspajak_penjualan                int64
# kelasbangunan_penjualan            object
# harga_penjualan                     int64
# tanggal_penjualan          datetime64[ns]
# dtype: object

# %% [markdown]
# Mereplace nomor wilayah dengan nama wilayah

# %%
df_baru = df_baru.replace({
                'wilayah': {
                    1: 'Manhattan',
                    2: 'Bronx',
                    3: 'Brooklyn',
                    4: 'Queens',
                    5: 'Staten Island'
                }
            }).astype(object)

# %%
df_baru
# Out:
#              wilayah                            kategori_bangunan kelas_pajak  \
# 0          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2A
# 3          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2B
# 4          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2A
# 6          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2B
# 9          Manhattan  08 RENTALS - ELEVATOR APARTMENTS                      2
# ...              ...                                          ...         ...
# 84543  Staten Island  02 TWO FAMILY DWELLINGS                               1
# 84544  Staten Island  02 TWO FAMILY DWELLINGS                               1
# 84545  Staten Island  02 TWO FAMILY DWELLINGS                               1
# 84546  Staten Island  22 STORE BUILDINGS                                    4
# 84547  Staten Island  35 INDOOR PUBLIC AND CULTURAL FACILITIES              4
#
# ...

# %% [markdown]
# Mengecek korelasi dari data yang kita punya

# %%
def plot_corr(df, size=11):
    corr = df.corr()
    fig, ax= plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr(df)

# %%
df_baru.corr()
# Out:
#                           blok    banyak  ZIP CODE  unit_hunian  \
# blok                  1.000000 -0.138230  0.145008    -0.042262
# banyak               -0.138230  1.000000 -0.070469    -0.034843
# ZIP CODE              0.145008 -0.070469  1.000000    -0.011122
# unit_hunian          -0.042262 -0.034843 -0.011122     1.000000
# unit_komersil        -0.003558 -0.008274 -0.000172     0.013337
# TOTAL UNITS          -0.037589 -0.031808 -0.009214     0.847441
# kotor_persegi        -0.044367 -0.042976 -0.017466     0.627589
# tahun_dibangun        0.082515 -0.394614  0.312317     0.027129
# kelaspajak_penjualan -0.204901  0.295954 -0.095424     0.023589
# harga_penjualan      -0.051667 -0.014495 -0.020298     0.125511
#
#                       unit_komersil  TOTAL UNITS  kotor_persegi  \
# blok                      -0.003558    -0.037589      -0.044367
# banyak                    -0.008274    -0.031808      -0.042976
# ZIP CODE                  -0.000172    -0.009214      -0.017466
# ...

# %% [markdown]
# ## Statistic Proses

# %% [markdown]
# ### Mean

# %%
df_baru
# Out:
#              wilayah                            kategori_bangunan kelas_pajak  \
# 0          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2A
# 3          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2B
# 4          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2A
# 6          Manhattan  07 RENTALS - WALKUP APARTMENTS                       2B
# 9          Manhattan  08 RENTALS - ELEVATOR APARTMENTS                      2
# ...              ...                                          ...         ...
# 84543  Staten Island  02 TWO FAMILY DWELLINGS                               1
# 84544  Staten Island  02 TWO FAMILY DWELLINGS                               1
# 84545  Staten Island  02 TWO FAMILY DWELLINGS                               1
# 84546  Staten Island  22 STORE BUILDINGS                                    4
# 84547  Staten Island  35 INDOOR PUBLIC AND CULTURAL FACILITIES              4
#
# ...

# %%
df_baru["harga_penjualan"].mean()
# Out:
# 1158309.9487222314

# %% [markdown]
# Rata-rata harga penjualan property di NYC sebesar Rp1.158.309

# %%
df_jml = df_baru.groupby('kategori_bangunan')['banyak'].sum()
df_jml
# Out:
# kategori_bangunan
# 01 ONE FAMILY DWELLINGS                         1054864
# 02 TWO FAMILY DWELLINGS                          694609
# 03 THREE FAMILY DWELLINGS                        187530
# 04 TAX CLASS 1 CONDOS                            852139
# 05 TAX CLASS 1 VACANT LAND                        71981
# 06 TAX CLASS 1 - OTHER                            16346
# 07 RENTALS - WALKUP APARTMENTS                   116259
# 08 RENTALS - ELEVATOR APARTMENTS                  12526
# 09 COOPS - WALKUP APARTMENTS                      43724
# 10 COOPS - ELEVATOR APARTMENTS                   363158
# 11 SPECIAL CONDO BILLING LOTS                      7501
# 11A CONDO-RENTALS                                 27842
# 12 CONDOS - WALKUP APARTMENTS                    508140
# 13 CONDOS - ELEVATOR APARTMENTS                 4636925
# 14 RENTALS - 4-10 UNIT                            16201
# 15 CONDOS - 2-10 UNIT RESIDENTIAL               1150045
# ...

# %%
df_jml.mean()
# Out:
# 239252.95744680852

# %% [markdown]
# Rata-rata bangunan yang di bangun di NYC sebanyak 239.252 bangunan.

# %%
df_jml = df_baru.groupby('kategori_bangunan')['banyak'].mean()
df_jml
# Out:
# kategori_bangunan
# 01 ONE FAMILY DWELLINGS                           73.581473
# 02 TWO FAMILY DWELLINGS                           53.567440
# 03 THREE FAMILY DWELLINGS                         51.505081
# 04 TAX CLASS 1 CONDOS                           1154.659892
# 05 TAX CLASS 1 VACANT LAND                       141.416503
# 06 TAX CLASS 1 - OTHER                           190.069767
# 07 RENTALS - WALKUP APARTMENTS                    42.523409
# 08 RENTALS - ELEVATOR APARTMENTS                  44.576512
# 09 COOPS - WALKUP APARTMENTS                      71.211726
# 10 COOPS - ELEVATOR APARTMENTS                   114.416509
# 11 SPECIAL CONDO BILLING LOTS                   7501.000000
# 11A CONDO-RENTALS                               1113.680000
# 12 CONDOS - WALKUP APARTMENTS                   1109.475983
# 13 CONDOS - ELEVATOR APARTMENTS                 1429.385018
# 14 RENTALS - 4-10 UNIT                            29.672161
# ...

# %% [markdown]
# Adapun rata-rata banyaknya bangunan perkategorinya yang di bangun di NYC dapat dilihat pada list diatas.

# %%
df_jml.max()
# Out:
# 7501.0

# %%
df_th = df_baru.groupby('tahun_dibangun')['banyak'].mean()
df_th
# Out:
# tahun_dibangun
# 0       1059.949878
# 1800     791.055556
# 1829      13.000000
# 1832      58.000000
# 1835      24.500000
#            ...
# 2013    1080.318367
# 2014     896.276243
# 2015     817.789588
# 2016     586.805616
# 2017     516.500000
# Name: banyak, Length: 151, dtype: float64

# %% [markdown]
# Adapun rata-rata banyaknya bangunan yang dibangun disetiap tahunnya dapat dilihat pada list diatas.

# %% [markdown]
# ### Median

# %%
df_jml = df_baru.groupby('kategori_bangunan')['TOTAL UNITS'].sum()
df_jml
# Out:
# kategori_bangunan
# 01 ONE FAMILY DWELLINGS                         14675
# 02 TWO FAMILY DWELLINGS                         26613
# 03 THREE FAMILY DWELLINGS                       10908
# 04 TAX CLASS 1 CONDOS                             712
# 05 TAX CLASS 1 VACANT LAND                        210
# 06 TAX CLASS 1 - OTHER                             19
# 07 RENTALS - WALKUP APARTMENTS                  29584
# 08 RENTALS - ELEVATOR APARTMENTS                23133
# 09 COOPS - WALKUP APARTMENTS                      569
# 10 COOPS - ELEVATOR APARTMENTS                   6845
# 11 SPECIAL CONDO BILLING LOTS                       0
# 11A CONDO-RENTALS                                1425
# 12 CONDOS - WALKUP APARTMENTS                     458
# 13 CONDOS - ELEVATOR APARTMENTS                  3046
# 14 RENTALS - 4-10 UNIT                           2926
# 15 CONDOS - 2-10 UNIT RESIDENTIAL                 914
# 16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT         55
# ...

# %%
df_jml.median()
# Out:
# 268.0

# %% [markdown]
# Median atau nilai tengah dari data jumlah unit perkategorinya adalah 268

# %% [markdown]
# ### Modus

# %%
df_baru['kategori_bangunan'].mod
# Out:
# <bound method flex_method_SERIES.<locals>.flex_wrapper of 0        07 RENTALS - WALKUP APARTMENTS
# 3        07 RENTALS - WALKUP APARTMENTS
# 4        07 RENTALS - WALKUP APARTMENTS
# 6        07 RENTALS - WALKUP APARTMENTS
# 9        08 RENTALS - ELEVATOR APARTMENTS
#                             ...
# 84543    02 TWO FAMILY DWELLINGS
# 84544    02 TWO FAMILY DWELLINGS
# 84545    02 TWO FAMILY DWELLINGS
# 84546    22 STORE BUILDINGS
# 84547    35 INDOOR PUBLIC AND CULTURAL FACILITIES
# Name: kategori_bangunan, Length: 47896, dtype: object>

# %% [markdown]
# Seringnya property yang dibangun dan terjual adalah property kategori 07 RENTALS - WALKUP APARTMENTS.

# %%
df_baru['tanggal_penjualan'].value_counts().mod
# Out:
# <bound method flex_method_SERIES.<locals>.flex_wrapper of 2016-12-22    328
# 2017-06-30    323
# 2016-10-06    314
# 2017-06-29    297
# 2017-02-28    291
#              ...
# 2017-01-08      1
# 2017-08-27      1
# 2017-08-06      1
# 2017-03-12      1
# 2017-06-04      1
# Name: tanggal_penjualan, Length: 362, dtype: int64>

# %% [markdown]
# Adapun banyaknya penjualan property terjadi pada tanggal 2016-12-22 sebanyak 328 penjualan dalam sehari.

# %% [markdown]
# ### Range

# %%
df_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47896 entries, 0 to 84547
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   wilayah                  47896 non-null  object
#  1   kategori_bangunan        47896 non-null  object
#  2   kelas_pajak              47896 non-null  object
#  3   blok                     47896 non-null  int64
#  4   banyak                   47896 non-null  int64
#  5   kelas_dibangun           47896 non-null  object
#  6   alamat                   47896 non-null  object
#  7   ZIP CODE                 47896 non-null  int64
#  8   unit_hunian              47896 non-null  int64
#  9   unit_komersil            47896 non-null  int64
#  10  TOTAL UNITS              47896 non-null  int64
#  11  tanah_persegi            47896 non-null  object
#  12  kotor_persegi            47896 non-null  int64
#  13  tahun_dibangun           47896 non-null  int64
# ...

# %%
df_max = df_baru['tanggal_penjualan'].value_counts().max()
df_max
# Out:
# 328

# %%
df_min = df_baru['tanggal_penjualan'].value_counts().min()
df_min
# Out:
# 1

# %%
range = df_max - df_min
range
# Out:
# 327

# %% [markdown]
# Ukuran rentang penjualan property di NYC adalah sebanyak 327 kali penjualan.

# %% [markdown]
# ### Variance

# %%
df_baru['tanah_persegi'] = df_baru['tanah_persegi'].astype(int)

# %%
df_baru.dtypes
# Out:
# wilayah                            object
# kategori_bangunan                  object
# kelas_pajak                        object
# blok                                int64
# banyak                              int64
# kelas_dibangun                     object
# alamat                             object
# ZIP CODE                            int64
# unit_hunian                         int64
# unit_komersil                       int64
# TOTAL UNITS                         int64
# tanah_persegi                       int64
# kotor_persegi                       int64
# tahun_dibangun                      int64
# kelaspajak_penjualan                int64
# kelasbangunan_penjualan            object
# harga_penjualan                     int64
# tanggal_penjualan          datetime64[ns]
# dtype: object

# %%
df_baru['tanah_persegi'].var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of 0          1633
# 3          2272
# 4          2369
# 6          1750
# 9          4489
#           ...
# 84543      2400
# 84544      2498
# 84545      4000
# 84546    208033
# 84547     10796
# Name: tanah_persegi, Length: 47896, dtype: int64>

# %% [markdown]
# Varians dari tanah persegi yang digunakan untuk bangunan properti di NYC adalah sebelah 1633

# %% [markdown]
# ### Standard Deviation

# %%
df_baru.std()
# Out:
# /var/folders/4y/l6qtpfl57p39zc4q106yjtqw0000gp/T/ipykernel_687/4254531222.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_baru.std()
# blok                                    3429.465212
# banyak                                   495.924368
# ZIP CODE                                1074.738599
# unit_hunian                                17.16993
# unit_komersil                             10.845527
# TOTAL UNITS                               20.427834
# tanah_persegi                          30549.843135
# kotor_persegi                          29205.105941
# tahun_dibangun                           463.083421
# kelaspajak_penjualan                       0.829171
# harga_penjualan                     13442643.850589
# tanggal_penjualan       103 days 14:44:28.789800528
# dtype: object

# %% [markdown]
# Berikut adalah ukuran penyebaran data yang digunakan dalam populasi data Properti NYC pada setiap bidangnya dengan nilai persebaran yang bereda-beda

# %%
df_baru.describe()
# Out:
#                blok        banyak      ZIP CODE   unit_hunian  unit_komersil  \
# count  47896.000000  47896.000000  47896.000000  47896.000000   47896.000000
# mean    4994.514970    234.777205  10940.163500      2.534888       0.237473
# std     3429.465212    495.924368   1074.738599     17.169930      10.845527
# min        1.000000      1.000000      0.000000      0.000000       0.000000
# 25%     2223.750000     21.000000  10469.000000      1.000000       0.000000
# 50%     4666.000000     45.000000  11217.000000      1.000000       0.000000
# 75%     7008.000000     94.000000  11238.000000      2.000000       0.000000
# max    16319.000000   9009.000000  11694.000000   1844.000000    2261.000000
#
#         TOTAL UNITS  tanah_persegi  kotor_persegi  tahun_dibangun  \
# count  47896.000000   4.789600e+04   4.789600e+04    47896.000000
# mean       2.791319   3.270904e+03   3.525875e+03     1828.445152
# std       20.427834   3.054984e+04   2.920511e+04      463.083421
# ...

# %% [markdown]
# ### Probability Distribution

# %%
df_baru['blok']
# Out:
# 0         392
# 3         402
# 4         404
# 6         406
# 9         387
#          ...
# 84543    7349
# 84544    7349
# 84545    7351
# 84546    7100
# 84547    7105
# Name: blok, Length: 47896, dtype: int64

# %%
prob = df_baru[['banyak','TOTAL UNITS']]
prob.plot.kde(ind=[250, 500, 750, 1000, 1250, 1500, 1750, 2000], bw_method=0.3, title="Probabilitas Properti dan Unit di NYC")
plt.xlabel('Jumlah')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Penjualan bangunan dan unit, keduanya memiliki frekuensi probabilitas yang berbeda, jika bangunan lebih cenderung naik turun dalam jumlah penjualannya, namun untuk unit tidak memiliki banyak perubahan dalam penjualannya.

# %% [markdown]
# ### Confidence Intervals

# %%
df_baru.dtypes
# Out:
# wilayah                            object
# kategori_bangunan                  object
# kelas_pajak                        object
# blok                                int64
# banyak                              int64
# kelas_dibangun                     object
# alamat                             object
# ZIP CODE                            int64
# unit_hunian                         int64
# unit_komersil                       int64
# TOTAL UNITS                         int64
# tanah_persegi                       int64
# kotor_persegi                       int64
# tahun_dibangun                      int64
# kelaspajak_penjualan                int64
# kelasbangunan_penjualan            object
# harga_penjualan                     int64
# tanggal_penjualan          datetime64[ns]
# dtype: object

# %%
interval =  df_baru['tanah_persegi']
st.t.interval(alpha=0.95, df=len(interval)-1, loc=np.mean(interval), scale=st.sem(interval))
# Out:
# (2997.302299462581, 3544.5052418769883)

# %% [markdown]
# Interval kepercayaan 95% untuk tinggi rata-rata tanah yang digunakan untuk berdirinya properti sebenarnya adalah (2997.302299462581, 3544.5052418769883)

# %% [markdown]
# ### Hypothesis Testing

# %%
sampel1 = df_baru['tanah_persegi']
sampel2 = df_baru['kotor_persegi']

st.ttest_ind(a=sampel1, b=sampel2)
# Out:
# Ttest_indResult(statistic=-1.3202967278138522, pvalue=0.18673912235774168)

# %% [markdown]
# Statistik uji t adalah –1.3202 dan nilai p dua sisi yang sesuai adalah 0.1867.
#
# Dua hipotesis untuk uji-t dua sampel khusus ini adalah sebagai berikut:
# H0 :  µ1 = µ2 (bobot rata-rata antara kedua bidang tanah sama)
# HA :  µ1 ≠ µ2 (berat rata-rata antara kedua bidang tanah tidak sama)
# Karena nilai p dari tes (0.1867) kurang dari 0.05, maka hipotesis nol ditolak.
#
# Ini berarti kita memiliki cukup bukti untuk mengatakan bahwa bidang rata-rata antara kedua tanah tidak sama.

# %% [markdown]
# ## Overall Analysis

# %% [markdown]
# Dari pemrosesan statistika data yang kita punya tentang properti di NYC diatas, dapat disimpulkan bahwa rata-rata harga penjualan property di NYC sebesar Rp1.158.309 dan rata-rata bangunan yang dibangun di NYC adalah bangunan kategori SPECIAL CONDO BILLING LOTS. Seringnya property yang dibangun dan terjual adalah property kategori 07 RENTALS - WALKUP APARTMENTS. Adapun banyaknya penjualan property terjadi pada tanggal 2016-12-22 sebanyak 328 penjualan dalam sehari. Adapun dari probabilitas penjualan bangunan dan unit, keduanya memiliki frekuensi probabilitas yang berbeda, jika bangunan lebih cenderung naik turun dalam jumlah penjualannya, namun untuk unit tidak memiliki banyak perubahan dalam penjualannya.
